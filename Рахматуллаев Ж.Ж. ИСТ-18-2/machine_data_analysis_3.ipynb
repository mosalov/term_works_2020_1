# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.927622</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>0.624287</td>
#       <td>-0.206993</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.090789</td>
#       <td>0.0</td>
#       <td>0.552201</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-2.117138</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.454038</td>
#       <td>0.159591</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.444548</td>
#       <td>0.0</td>
#       <td>0.715169</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.529863</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.454038</td>
#       <td>-0.864692</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.931137</td>
#       <td>0.0</td>
#       <td>0.398844</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.253797</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>-0.141353</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.141680</td>
#       <td>0.0</td>
#       <td>0.265991</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.355054</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.335019</td>
#       <td>2.100829</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.601134</td>
#       <td>1.0</td>
#       <td>0.210865</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.568560</td>
#       <td>-1.150460</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.008368</td>
#       <td>0.0</td>
#       <td>0.145476</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.253797</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.568560</td>
#       <td>1.054214</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.212382</td>
#       <td>0.0</td>
#       <td>0.379044</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.125867</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>0.431579</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.966733</td>
#       <td>0.0</td>
#       <td>0.323580</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.170168</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.909866</td>
#       <td>-0.982712</td>
#       <td>1.0</td>
#       <td>0.397544</td>
#       <td>0.563348</td>
#       <td>0.0</td>
#       <td>0.179818</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.679061</td>
#       <td>-1.750157</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.002123</td>
#       <td>0.0</td>
#       <td>0.436427</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.iloc[:, [*range(1,13),12]].values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
input_layer_size = 13
first_hidden_layer_size = 15
second_hidden_layer_size = 15
output_layer_size = 1
epochs_number = 50
batch_size = 36

# %%
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/50
# 242/242 [==============================] - 0s 589us/step - loss: 1.7424 - mean_absolute_error: 1.0034 - mean_squared_error: 1.7424 - val_loss: 0.9772 - val_mean_absolute_error: 0.7894 - val_mean_squared_error: 0.9772
# Epoch 2/50
# 242/242 [==============================] - 0s 44us/step - loss: 1.4875 - mean_absolute_error: 0.9418 - mean_squared_error: 1.4875 - val_loss: 0.8858 - val_mean_absolute_error: 0.7562 - val_mean_squared_error: 0.8858
# Epoch 3/50
# 242/242 [==============================] - 0s 46us/step - loss: 1.2955 - mean_absolute_error: 0.8873 - mean_squared_error: 1.2955 - val_loss: 0.8302 - val_mean_absolute_error: 0.7274 - val_mean_squared_error: 0.8302
# Epoch 4/50
# 242/242 [==============================] - 0s 46us/step - loss: 1.1479 - mean_absolute_error: 0.8492 - mean_squared_error: 1.1479 - val_loss: 0.8010 - val_mean_absolute_error: 0.7148 - val_mean_squared_error: 0.8010
# Epoch 5/50
# 242/242 [==============================] - 0s 47us/step - loss: 1.0542 - mean_absolute_error: 0.8273 - mean_squared_error: 1.0542 - val_loss: 0.7935 - val_mean_absolute_error: 0.7114 - val_mean_squared_error: 0.7935
# Epoch 6/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.9828 - mean_absolute_error: 0.8124 - mean_squared_error: 0.9828 - val_loss: 0.7961 - val_mean_absolute_error: 0.7101 - val_mean_squared_error: 0.7961
# Epoch 7/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.9381 - mean_absolute_error: 0.7998 - mean_squared_error: 0.9381 - val_loss: 0.7966 - val_mean_absolute_error: 0.7140 - val_mean_squared_error: 0.7966
# Epoch 8/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.9092 - mean_absolute_error: 0.7899 - mean_squared_error: 0.9092 - val_loss: 0.7953 - val_mean_absolute_error: 0.7157 - val_mean_squared_error: 0.7953
# Epoch 9/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.8846 - mean_absolute_error: 0.7792 - mean_squared_error: 0.8846 - val_loss: 0.7865 - val_mean_absolute_error: 0.7151 - val_mean_squared_error: 0.7865
# Epoch 10/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.8663 - mean_absolute_error: 0.7707 - mean_squared_error: 0.8663 - val_loss: 0.7746 - val_mean_absolute_error: 0.7130 - val_mean_squared_error: 0.7746
# Epoch 11/50
# 242/242 [==============================] - 0s 47us/step - loss: 0.8522 - mean_absolute_error: 0.7635 - mean_squared_error: 0.8522 - val_loss: 0.7623 - val_mean_absolute_error: 0.7100 - val_mean_squared_error: 0.7623
# Epoch 12/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.8410 - mean_absolute_error: 0.7568 - mean_squared_error: 0.8410 - val_loss: 0.7516 - val_mean_absolute_error: 0.7061 - val_mean_squared_error: 0.7516
# Epoch 13/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.8289 - mean_absolute_error: 0.7502 - mean_squared_error: 0.8289 - val_loss: 0.7396 - val_mean_absolute_error: 0.7020 - val_mean_squared_error: 0.7396
# Epoch 14/50
# 242/242 [==============================] - 0s 47us/step - loss: 0.8209 - mean_absolute_error: 0.7456 - mean_squared_error: 0.8209 - val_loss: 0.7313 - val_mean_absolute_error: 0.6988 - val_mean_squared_error: 0.7313
# Epoch 15/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.8101 - mean_absolute_error: 0.7401 - mean_squared_error: 0.8101 - val_loss: 0.7216 - val_mean_absolute_error: 0.6943 - val_mean_squared_error: 0.7216
# Epoch 16/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.8034 - mean_absolute_error: 0.7363 - mean_squared_error: 0.8034 - val_loss: 0.7137 - val_mean_absolute_error: 0.6902 - val_mean_squared_error: 0.7137
# Epoch 17/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7959 - mean_absolute_error: 0.7328 - mean_squared_error: 0.7959 - val_loss: 0.7061 - val_mean_absolute_error: 0.6868 - val_mean_squared_error: 0.7061
# Epoch 18/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.7896 - mean_absolute_error: 0.7300 - mean_squared_error: 0.7896 - val_loss: 0.6981 - val_mean_absolute_error: 0.6831 - val_mean_squared_error: 0.6981
# Epoch 19/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.7828 - mean_absolute_error: 0.7269 - mean_squared_error: 0.7828 - val_loss: 0.6930 - val_mean_absolute_error: 0.6807 - val_mean_squared_error: 0.6930
# Epoch 20/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.7764 - mean_absolute_error: 0.7239 - mean_squared_error: 0.7764 - val_loss: 0.6928 - val_mean_absolute_error: 0.6803 - val_mean_squared_error: 0.6928
# Epoch 21/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7708 - mean_absolute_error: 0.7216 - mean_squared_error: 0.7708 - val_loss: 0.6854 - val_mean_absolute_error: 0.6767 - val_mean_squared_error: 0.6854
# Epoch 22/50
# 242/242 [==============================] - 0s 43us/step - loss: 0.7641 - mean_absolute_error: 0.7181 - mean_squared_error: 0.7641 - val_loss: 0.6832 - val_mean_absolute_error: 0.6752 - val_mean_squared_error: 0.6832
# Epoch 23/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7585 - mean_absolute_error: 0.7159 - mean_squared_error: 0.7585 - val_loss: 0.6793 - val_mean_absolute_error: 0.6726 - val_mean_squared_error: 0.6793
# Epoch 24/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7535 - mean_absolute_error: 0.7133 - mean_squared_error: 0.7535 - val_loss: 0.6714 - val_mean_absolute_error: 0.6681 - val_mean_squared_error: 0.6714
# Epoch 25/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7474 - mean_absolute_error: 0.7102 - mean_squared_error: 0.7474 - val_loss: 0.6707 - val_mean_absolute_error: 0.6678 - val_mean_squared_error: 0.6707
# Epoch 26/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7426 - mean_absolute_error: 0.7079 - mean_squared_error: 0.7426 - val_loss: 0.6666 - val_mean_absolute_error: 0.6654 - val_mean_squared_error: 0.6666
# Epoch 27/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7385 - mean_absolute_error: 0.7051 - mean_squared_error: 0.7385 - val_loss: 0.6598 - val_mean_absolute_error: 0.6623 - val_mean_squared_error: 0.6598
# Epoch 28/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.7337 - mean_absolute_error: 0.7023 - mean_squared_error: 0.7337 - val_loss: 0.6584 - val_mean_absolute_error: 0.6610 - val_mean_squared_error: 0.6584
# Epoch 29/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.7290 - mean_absolute_error: 0.6998 - mean_squared_error: 0.7290 - val_loss: 0.6540 - val_mean_absolute_error: 0.6589 - val_mean_squared_error: 0.6540
# Epoch 30/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.7253 - mean_absolute_error: 0.6974 - mean_squared_error: 0.7253 - val_loss: 0.6487 - val_mean_absolute_error: 0.6566 - val_mean_squared_error: 0.6487
# Epoch 31/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7204 - mean_absolute_error: 0.6945 - mean_squared_error: 0.7204 - val_loss: 0.6432 - val_mean_absolute_error: 0.6539 - val_mean_squared_error: 0.6432
# Epoch 32/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.7169 - mean_absolute_error: 0.6923 - mean_squared_error: 0.7169 - val_loss: 0.6413 - val_mean_absolute_error: 0.6523 - val_mean_squared_error: 0.6413
# Epoch 33/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7133 - mean_absolute_error: 0.6901 - mean_squared_error: 0.7133 - val_loss: 0.6330 - val_mean_absolute_error: 0.6490 - val_mean_squared_error: 0.6330
# Epoch 34/50
# 242/242 [==============================] - 0s 43us/step - loss: 0.7089 - mean_absolute_error: 0.6876 - mean_squared_error: 0.7089 - val_loss: 0.6300 - val_mean_absolute_error: 0.6476 - val_mean_squared_error: 0.6300
# Epoch 35/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.7045 - mean_absolute_error: 0.6849 - mean_squared_error: 0.7045 - val_loss: 0.6297 - val_mean_absolute_error: 0.6466 - val_mean_squared_error: 0.6297
# Epoch 36/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.7016 - mean_absolute_error: 0.6828 - mean_squared_error: 0.7016 - val_loss: 0.6203 - val_mean_absolute_error: 0.6426 - val_mean_squared_error: 0.6203
# Epoch 37/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.6975 - mean_absolute_error: 0.6807 - mean_squared_error: 0.6975 - val_loss: 0.6237 - val_mean_absolute_error: 0.6428 - val_mean_squared_error: 0.6237
# Epoch 38/50
# 242/242 [==============================] - 0s 43us/step - loss: 0.6939 - mean_absolute_error: 0.6781 - mean_squared_error: 0.6939 - val_loss: 0.6220 - val_mean_absolute_error: 0.6416 - val_mean_squared_error: 0.6220
# Epoch 39/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.6915 - mean_absolute_error: 0.6764 - mean_squared_error: 0.6915 - val_loss: 0.6100 - val_mean_absolute_error: 0.6372 - val_mean_squared_error: 0.6100
# Epoch 40/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.6868 - mean_absolute_error: 0.6739 - mean_squared_error: 0.6868 - val_loss: 0.6074 - val_mean_absolute_error: 0.6355 - val_mean_squared_error: 0.6074
# Epoch 41/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.6824 - mean_absolute_error: 0.6710 - mean_squared_error: 0.6824 - val_loss: 0.6061 - val_mean_absolute_error: 0.6345 - val_mean_squared_error: 0.6061
# Epoch 42/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.6791 - mean_absolute_error: 0.6691 - mean_squared_error: 0.6791 - val_loss: 0.6050 - val_mean_absolute_error: 0.6332 - val_mean_squared_error: 0.6050
# Epoch 43/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.6765 - mean_absolute_error: 0.6676 - mean_squared_error: 0.6765 - val_loss: 0.6082 - val_mean_absolute_error: 0.6329 - val_mean_squared_error: 0.6082
# Epoch 44/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.6727 - mean_absolute_error: 0.6656 - mean_squared_error: 0.6727 - val_loss: 0.6002 - val_mean_absolute_error: 0.6297 - val_mean_squared_error: 0.6002
# Epoch 45/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.6691 - mean_absolute_error: 0.6634 - mean_squared_error: 0.6691 - val_loss: 0.5955 - val_mean_absolute_error: 0.6271 - val_mean_squared_error: 0.5955
# Epoch 46/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.6665 - mean_absolute_error: 0.6621 - mean_squared_error: 0.6665 - val_loss: 0.5979 - val_mean_absolute_error: 0.6273 - val_mean_squared_error: 0.5979
# Epoch 47/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.6631 - mean_absolute_error: 0.6596 - mean_squared_error: 0.6631 - val_loss: 0.5933 - val_mean_absolute_error: 0.6248 - val_mean_squared_error: 0.5933
# Epoch 48/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.6597 - mean_absolute_error: 0.6576 - mean_squared_error: 0.6597 - val_loss: 0.5906 - val_mean_absolute_error: 0.6229 - val_mean_squared_error: 0.5906
# Epoch 49/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.6578 - mean_absolute_error: 0.6560 - mean_squared_error: 0.6578 - val_loss: 0.5846 - val_mean_absolute_error: 0.6200 - val_mean_squared_error: 0.5846
# Epoch 50/50
# 242/242 [==============================] - 0s 44us/step - loss: 0.6542 - mean_absolute_error: 0.6538 - mean_squared_error: 0.6542 - val_loss: 0.5810 - val_mean_absolute_error: 0.6183 - val_mean_squared_error: 0.5810

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.8068151844729256
# 0.7622179462446259

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9883992671966553, p = 0.04831882193684578
# Test k = 0.9850327968597412, p = 0.6614956259727478

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9918466806411743, p_s = 0.09383342415094376
# k_n = 4.344194759858367, p_n = 0.11393839402709832

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('3_SimpleNeuralNetwork.h5')
