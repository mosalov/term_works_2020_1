# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.927622</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>0.624287</td>
#       <td>-0.206993</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.090789</td>
#       <td>0.0</td>
#       <td>0.552201</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-2.117138</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.454038</td>
#       <td>0.159591</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.444548</td>
#       <td>0.0</td>
#       <td>0.715169</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.529863</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.454038</td>
#       <td>-0.864692</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.931137</td>
#       <td>0.0</td>
#       <td>0.398844</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.253797</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>-0.141353</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.141680</td>
#       <td>0.0</td>
#       <td>0.265991</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.355054</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.335019</td>
#       <td>2.100829</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.601134</td>
#       <td>1.0</td>
#       <td>0.210865</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.568560</td>
#       <td>-1.150460</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.008368</td>
#       <td>0.0</td>
#       <td>0.145476</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.253797</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.568560</td>
#       <td>1.054214</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.212382</td>
#       <td>0.0</td>
#       <td>0.379044</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.125867</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>0.431579</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.966733</td>
#       <td>0.0</td>
#       <td>0.323580</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.170168</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.909866</td>
#       <td>-0.982712</td>
#       <td>1.0</td>
#       <td>0.397544</td>
#       <td>0.563348</td>
#       <td>0.0</td>
#       <td>0.179818</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.679061</td>
#       <td>-1.750157</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.002123</td>
#       <td>0.0</td>
#       <td>0.436427</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.iloc[:, [*range(1,13),12]].values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
input_layer_size = 13
first_hidden_layer_size = 15
second_hidden_layer_size = 15
output_layer_size = 1
epochs_number = 50
batch_size = 16

# %%
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/50
# 242/242 [==============================] - 0s 655us/step - loss: 2.4994 - mean_absolute_error: 1.2173 - mean_squared_error: 2.4994 - val_loss: 1.6148 - val_mean_absolute_error: 0.9447 - val_mean_squared_error: 1.6148
# Epoch 2/50
# 242/242 [==============================] - 0s 90us/step - loss: 1.7831 - mean_absolute_error: 1.0258 - mean_squared_error: 1.7831 - val_loss: 1.2290 - val_mean_absolute_error: 0.8385 - val_mean_squared_error: 1.2290
# Epoch 3/50
# 242/242 [==============================] - 0s 88us/step - loss: 1.3710 - mean_absolute_error: 0.9157 - mean_squared_error: 1.3710 - val_loss: 1.0280 - val_mean_absolute_error: 0.7874 - val_mean_squared_error: 1.0280
# Epoch 4/50
# 242/242 [==============================] - 0s 89us/step - loss: 1.1414 - mean_absolute_error: 0.8460 - mean_squared_error: 1.1414 - val_loss: 0.9162 - val_mean_absolute_error: 0.7613 - val_mean_squared_error: 0.9162
# Epoch 5/50
# 242/242 [==============================] - 0s 88us/step - loss: 1.0301 - mean_absolute_error: 0.8170 - mean_squared_error: 1.0301 - val_loss: 0.8651 - val_mean_absolute_error: 0.7456 - val_mean_squared_error: 0.8651
# Epoch 6/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.9769 - mean_absolute_error: 0.7974 - mean_squared_error: 0.9769 - val_loss: 0.8267 - val_mean_absolute_error: 0.7292 - val_mean_squared_error: 0.8267
# Epoch 7/50
# 242/242 [==============================] - 0s 86us/step - loss: 0.9403 - mean_absolute_error: 0.7847 - mean_squared_error: 0.9403 - val_loss: 0.7993 - val_mean_absolute_error: 0.7258 - val_mean_squared_error: 0.7993
# Epoch 8/50
# 242/242 [==============================] - 0s 86us/step - loss: 0.9139 - mean_absolute_error: 0.7762 - mean_squared_error: 0.9139 - val_loss: 0.7740 - val_mean_absolute_error: 0.7143 - val_mean_squared_error: 0.7740
# Epoch 9/50
# 242/242 [==============================] - 0s 85us/step - loss: 0.8903 - mean_absolute_error: 0.7677 - mean_squared_error: 0.8903 - val_loss: 0.7500 - val_mean_absolute_error: 0.7004 - val_mean_squared_error: 0.7500
# Epoch 10/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.8709 - mean_absolute_error: 0.7605 - mean_squared_error: 0.8709 - val_loss: 0.7337 - val_mean_absolute_error: 0.6983 - val_mean_squared_error: 0.7337
# Epoch 11/50
# 242/242 [==============================] - 0s 90us/step - loss: 0.8542 - mean_absolute_error: 0.7539 - mean_squared_error: 0.8542 - val_loss: 0.7112 - val_mean_absolute_error: 0.6829 - val_mean_squared_error: 0.7112
# Epoch 12/50
# 242/242 [==============================] - 0s 86us/step - loss: 0.8364 - mean_absolute_error: 0.7450 - mean_squared_error: 0.8364 - val_loss: 0.7006 - val_mean_absolute_error: 0.6799 - val_mean_squared_error: 0.7006
# Epoch 13/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.8227 - mean_absolute_error: 0.7398 - mean_squared_error: 0.8227 - val_loss: 0.6937 - val_mean_absolute_error: 0.6815 - val_mean_squared_error: 0.6937
# Epoch 14/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.8097 - mean_absolute_error: 0.7337 - mean_squared_error: 0.8097 - val_loss: 0.6825 - val_mean_absolute_error: 0.6743 - val_mean_squared_error: 0.6825
# Epoch 15/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.7997 - mean_absolute_error: 0.7292 - mean_squared_error: 0.7997 - val_loss: 0.6726 - val_mean_absolute_error: 0.6611 - val_mean_squared_error: 0.6726
# Epoch 16/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.7871 - mean_absolute_error: 0.7232 - mean_squared_error: 0.7871 - val_loss: 0.6631 - val_mean_absolute_error: 0.6537 - val_mean_squared_error: 0.6631
# Epoch 17/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.7735 - mean_absolute_error: 0.7168 - mean_squared_error: 0.7735 - val_loss: 0.6515 - val_mean_absolute_error: 0.6499 - val_mean_squared_error: 0.6515
# Epoch 18/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.7626 - mean_absolute_error: 0.7114 - mean_squared_error: 0.7626 - val_loss: 0.6396 - val_mean_absolute_error: 0.6456 - val_mean_squared_error: 0.6396
# Epoch 19/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.7489 - mean_absolute_error: 0.7040 - mean_squared_error: 0.7489 - val_loss: 0.6365 - val_mean_absolute_error: 0.6487 - val_mean_squared_error: 0.6365
# Epoch 20/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.7407 - mean_absolute_error: 0.7004 - mean_squared_error: 0.7407 - val_loss: 0.6252 - val_mean_absolute_error: 0.6400 - val_mean_squared_error: 0.6252
# Epoch 21/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.7296 - mean_absolute_error: 0.6954 - mean_squared_error: 0.7296 - val_loss: 0.6203 - val_mean_absolute_error: 0.6385 - val_mean_squared_error: 0.6203
# Epoch 22/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.7217 - mean_absolute_error: 0.6908 - mean_squared_error: 0.7217 - val_loss: 0.6171 - val_mean_absolute_error: 0.6374 - val_mean_squared_error: 0.6171
# Epoch 23/50
# 242/242 [==============================] - 0s 89us/step - loss: 0.7120 - mean_absolute_error: 0.6871 - mean_squared_error: 0.7120 - val_loss: 0.6107 - val_mean_absolute_error: 0.6338 - val_mean_squared_error: 0.6107
# Epoch 24/50
# 242/242 [==============================] - 0s 89us/step - loss: 0.7026 - mean_absolute_error: 0.6818 - mean_squared_error: 0.7026 - val_loss: 0.6030 - val_mean_absolute_error: 0.6314 - val_mean_squared_error: 0.6030
# Epoch 25/50
# 242/242 [==============================] - 0s 91us/step - loss: 0.6930 - mean_absolute_error: 0.6775 - mean_squared_error: 0.6930 - val_loss: 0.5959 - val_mean_absolute_error: 0.6247 - val_mean_squared_error: 0.5959
# Epoch 26/50
# 242/242 [==============================] - 0s 85us/step - loss: 0.6842 - mean_absolute_error: 0.6729 - mean_squared_error: 0.6842 - val_loss: 0.5898 - val_mean_absolute_error: 0.6211 - val_mean_squared_error: 0.5898
# Epoch 27/50
# 242/242 [==============================] - 0s 85us/step - loss: 0.6766 - mean_absolute_error: 0.6692 - mean_squared_error: 0.6766 - val_loss: 0.5876 - val_mean_absolute_error: 0.6201 - val_mean_squared_error: 0.5876
# Epoch 28/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.6675 - mean_absolute_error: 0.6647 - mean_squared_error: 0.6675 - val_loss: 0.5882 - val_mean_absolute_error: 0.6207 - val_mean_squared_error: 0.5882
# Epoch 29/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.6611 - mean_absolute_error: 0.6612 - mean_squared_error: 0.6611 - val_loss: 0.5831 - val_mean_absolute_error: 0.6135 - val_mean_squared_error: 0.5831
# Epoch 30/50
# 242/242 [==============================] - 0s 90us/step - loss: 0.6569 - mean_absolute_error: 0.6589 - mean_squared_error: 0.6569 - val_loss: 0.5802 - val_mean_absolute_error: 0.6067 - val_mean_squared_error: 0.5802
# Epoch 31/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.6506 - mean_absolute_error: 0.6548 - mean_squared_error: 0.6506 - val_loss: 0.5793 - val_mean_absolute_error: 0.6066 - val_mean_squared_error: 0.5793
# Epoch 32/50
# 242/242 [==============================] - 0s 89us/step - loss: 0.6476 - mean_absolute_error: 0.6524 - mean_squared_error: 0.6476 - val_loss: 0.5814 - val_mean_absolute_error: 0.6139 - val_mean_squared_error: 0.5814
# Epoch 33/50
# 242/242 [==============================] - 0s 90us/step - loss: 0.6411 - mean_absolute_error: 0.6513 - mean_squared_error: 0.6411 - val_loss: 0.5843 - val_mean_absolute_error: 0.6017 - val_mean_squared_error: 0.5843
# Epoch 34/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.6421 - mean_absolute_error: 0.6486 - mean_squared_error: 0.6421 - val_loss: 0.5778 - val_mean_absolute_error: 0.6004 - val_mean_squared_error: 0.5778
# Epoch 35/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.6325 - mean_absolute_error: 0.6434 - mean_squared_error: 0.6325 - val_loss: 0.5801 - val_mean_absolute_error: 0.6082 - val_mean_squared_error: 0.5801
# Epoch 36/50
# 242/242 [==============================] - 0s 85us/step - loss: 0.6267 - mean_absolute_error: 0.6404 - mean_squared_error: 0.6267 - val_loss: 0.5789 - val_mean_absolute_error: 0.6108 - val_mean_squared_error: 0.5789
# Epoch 37/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.6236 - mean_absolute_error: 0.6376 - mean_squared_error: 0.6236 - val_loss: 0.5745 - val_mean_absolute_error: 0.6042 - val_mean_squared_error: 0.5745
# Epoch 38/50
# 242/242 [==============================] - 0s 86us/step - loss: 0.6230 - mean_absolute_error: 0.6372 - mean_squared_error: 0.6230 - val_loss: 0.5745 - val_mean_absolute_error: 0.6012 - val_mean_squared_error: 0.5745
# Epoch 39/50
# 242/242 [==============================] - 0s 90us/step - loss: 0.6261 - mean_absolute_error: 0.6386 - mean_squared_error: 0.6261 - val_loss: 0.5664 - val_mean_absolute_error: 0.5854 - val_mean_squared_error: 0.5664
# Epoch 40/50
# 242/242 [==============================] - 0s 89us/step - loss: 0.6143 - mean_absolute_error: 0.6302 - mean_squared_error: 0.6143 - val_loss: 0.5631 - val_mean_absolute_error: 0.5956 - val_mean_squared_error: 0.5631
# Epoch 41/50
# 242/242 [==============================] - 0s 89us/step - loss: 0.6148 - mean_absolute_error: 0.6262 - mean_squared_error: 0.6148 - val_loss: 0.5697 - val_mean_absolute_error: 0.6110 - val_mean_squared_error: 0.5697
# Epoch 42/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.6080 - mean_absolute_error: 0.6218 - mean_squared_error: 0.6080 - val_loss: 0.5585 - val_mean_absolute_error: 0.5853 - val_mean_squared_error: 0.5585
# Epoch 43/50
# 242/242 [==============================] - 0s 86us/step - loss: 0.6243 - mean_absolute_error: 0.6311 - mean_squared_error: 0.6243 - val_loss: 0.5632 - val_mean_absolute_error: 0.5816 - val_mean_squared_error: 0.5632
# Epoch 44/50
# 242/242 [==============================] - 0s 89us/step - loss: 0.6045 - mean_absolute_error: 0.6234 - mean_squared_error: 0.6045 - val_loss: 0.5632 - val_mean_absolute_error: 0.6024 - val_mean_squared_error: 0.5632
# Epoch 45/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.6015 - mean_absolute_error: 0.6218 - mean_squared_error: 0.6015 - val_loss: 0.5612 - val_mean_absolute_error: 0.5959 - val_mean_squared_error: 0.5612
# Epoch 46/50
# 242/242 [==============================] - 0s 90us/step - loss: 0.5982 - mean_absolute_error: 0.6206 - mean_squared_error: 0.5982 - val_loss: 0.5622 - val_mean_absolute_error: 0.5942 - val_mean_squared_error: 0.5622
# Epoch 47/50
# 242/242 [==============================] - 0s 89us/step - loss: 0.5946 - mean_absolute_error: 0.6149 - mean_squared_error: 0.5946 - val_loss: 0.5736 - val_mean_absolute_error: 0.6122 - val_mean_squared_error: 0.5736
# Epoch 48/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.5988 - mean_absolute_error: 0.6132 - mean_squared_error: 0.5988 - val_loss: 0.5663 - val_mean_absolute_error: 0.5985 - val_mean_squared_error: 0.5663
# Epoch 49/50
# 242/242 [==============================] - 0s 87us/step - loss: 0.5907 - mean_absolute_error: 0.6121 - mean_squared_error: 0.5907 - val_loss: 0.5658 - val_mean_absolute_error: 0.5991 - val_mean_squared_error: 0.5658
# Epoch 50/50
# 242/242 [==============================] - 0s 89us/step - loss: 0.5878 - mean_absolute_error: 0.6117 - mean_squared_error: 0.5878 - val_loss: 0.5664 - val_mean_absolute_error: 0.6018 - val_mean_squared_error: 0.5664

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.7630640785054797
# 0.7525744889253734

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.991723358631134, p = 0.1902184635400772
# Test k = 0.9433117508888245, p = 0.007012054789811373

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9888736009597778, p_s = 0.020297696813941002
# k_n = 6.150203118164494, p_n = 0.0461849376436099

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('1_SimpleNeuralNetwork.h5')
